# %%
import pandas as pd
import os

# %% [markdown]
# # Election Results README

# %%
la_names = pd.read_csv("./field_names_gen.csv")
la_names["Clean"] = la_names["0"].apply(lambda x: x.split(" (")[0])

# %%
la_names["0"][5]
# Out:
# 'Donald J. Trump, "JD" Vance Republican (REP)-:-Presidential Electors'

# %%
la_names.sort_values("1", inplace = True)

# %%
la_names
# Out:
#                                                     0           1  \
# 1   NO-:-CA No. 1 (Act No. 408, 2024 - HB 300) -- ...     G24A1NO
# 0   YES-:-CA No. 1 (Act No. 408, 2024 - HB 300) --...    G24A1YES
# 2   Kamala D. Harris, Tim Walz Democratic (DEM)-:-...  G24PREDHAR
# 4   Chase Oliver, Mike ter Maat Libertarian (LBT)-...  G24PRELOLI
# 10  Claudia de la Cruz, Karina Garcia Socialism an...  G24PREOCRU
# 11  Rachele Fruit, Dennis Richter Socialist Worker...  G24PREOFRU
# 12  Robert F. Kennedy, Jr., Nicole Shanahan We The...  G24PREOKEN
# 8   Mattie Preston, Shannel Conner Godliness, Trut...  G24PREOPRE
# 6   Peter Sonski, Lauren Onak American Solidarity ...  G24PREOSON
# 3   Jill Stein, Ajamu Baraka Green (GRN)-:-Preside...  G24PREOSTE
# 7   Randall Terry, Stephen Broden Constitution Par...  G24PREOTER
# 9   Cornel West, Melina Abdullah Justice For All (...  G24PREOWES
# 5   Donald J. Trump, "JD" Vance Republican (REP)-:...  G24PRERTRU
# 28  Mel Manuel (DEM)-:-U. S. Representative -- 1st...  GCON01DMAN
# 27  J. "Frankie" Hyers (NOPTY)-:-U. S. Representat...  GCON01NHYE
# 26  Randall Arrington (REP)-:-U. S. Representative...  GCON01RARR
# 29  Steve Scalise (REP)-:-U. S. Representative -- ...  GCON01RSCA
# 30  Ross Shales (REP)-:-U. S. Representative -- 1s...  GCON01RSHA
# 16  Troy A. Carter, Sr. (DEM)-:-U. S. Representati...  GCON02DCAR
# 17  Devin Davis (DEM)-:-U. S. Representative -- 2n...  GCON02DDAV
# 18  Devin Lance Graham (REP)-:-U. S. Representativ...  GCON02RGRA
# 19  Christy Lynch (REP)-:-U. S. Representative -- ...  GCON02RLYN
# 20  Shondrell Perrilloux (REP)-:-U. S. Representat...  GCON02RPER
# 33  Priscilla Gonzalez (DEM)-:-U. S. Representativ...  GCON03DGON
# 36  Sadi Summerlin (DEM)-:-U. S. Representative --...  GCON03DSUM
# 34  Clay Higgins (REP)-:-U. S. Representative -- 3...  GCON03RHIG
# 35  "Xan" John (REP)-:-U. S. Representative -- 3rd...  GCON03RJOH
# 31  "Mike" Johnson (REP)-:-U. S. Representative --...  GCON04RJOH
# 32  Joshua Morott (REP)-:-U. S. Representative -- ...  GCON04RMOR
# 15  Michael Vallien, Jr. (DEM)-:-U. S. Representat...  GCON05DVAL
# 13  Julia Letlow (REP)-:-U. S. Representative -- 5...  GCON05RLET
# 14  M.V. "Vinny" Mendoza (REP)-:-U. S. Representat...  GCON05RMEN
# 21  Quentin Anthony Anderson (DEM)-:-U. S. Represe...  GCON06DAND
# 22  Cleo Fields (DEM)-:-U. S. Representative -- 6t...  GCON06DFIE
# 24  Wilken Jones, Jr. (DEM)-:-U. S. Representative...  GCON06DJON
# 25  Peter Williams (DEM)-:-U. S. Representative --...  GCON06DWIL
# 23  Elbert Guillory (REP)-:-U. S. Representative -...  GCON06RGUI
#
#                                                 Clean
# 1                                       NO-:-CA No. 1
# 0                                      YES-:-CA No. 1
# 2               Kamala D. Harris, Tim Walz Democratic
# 4             Chase Oliver, Mike ter Maat Libertarian
# 10  Claudia de la Cruz, Karina Garcia Socialism an...
# 11  Rachele Fruit, Dennis Richter Socialist Worker...
# 12  Robert F. Kennedy, Jr., Nicole Shanahan We The...
# 8   Mattie Preston, Shannel Conner Godliness, Trut...
# 6   Peter Sonski, Lauren Onak American Solidarity ...
# 3                      Jill Stein, Ajamu Baraka Green
# 7    Randall Terry, Stephen Broden Constitution Party
# 9        Cornel West, Melina Abdullah Justice For All
# 5              Donald J. Trump, "JD" Vance Republican
# 28                                         Mel Manuel
# 27                                 J. "Frankie" Hyers
# 26                                  Randall Arrington
# 29                                      Steve Scalise
# 30                                        Ross Shales
# 16                                Troy A. Carter, Sr.
# 17                                        Devin Davis
# 18                                 Devin Lance Graham
# 19                                      Christy Lynch
# 20                               Shondrell Perrilloux
# 33                                 Priscilla Gonzalez
# 36                                     Sadi Summerlin
# 34                                       Clay Higgins
# 35                                         "Xan" John
# 31                                     "Mike" Johnson
# 32                                      Joshua Morott
# 15                               Michael Vallien, Jr.
# 13                                       Julia Letlow
# 14                               M.V. "Vinny" Mendoza
# 21                           Quentin Anthony Anderson
# 22                                        Cleo Fields
# 24                                  Wilken Jones, Jr.
# 25                                     Peter Williams
# 23                                    Elbert Guillory

# %%
fields_dict = dict(zip(la_names["1"], la_names["0"]))
myKeys = list(fields_dict.keys())
myKeys.sort()
fields_dict = {i: fields_dict[i] for i in myKeys}

# %%
turnout_cols = ['TOTAL_Reg', 'WHITE_Reg', 'BLACK_Reg', 'OTHER_Reg',
       'TOTAL_Dem_Reg', 'WHITE_Dem_Reg', 'BLACK_Dem_Reg', 'OTHER_Dem_Reg',
       'TOTAL_Rep_Reg', 'WHITE_Rep_Reg', 'BLACK_Rep_Reg', 'OTHER_Rep_Reg',
       'TOTAL_Oth_Reg', 'WHITE_Oth_Reg', 'BLACK_Oth_Reg', 'OTHER_Oth_Reg',
       'TOTAL_Voted', 'WHITE_Voted', 'BLACK_Voted', 'OTHER_Voted',
       'TOTAL_Dem_Voted', 'WHITE_Dem_Voted', 'BLACK_Dem_Voted',
       'OTHER_Dem_Voted', 'TOTAL_Rep_Voted', 'WHITE_Rep_Voted',
       'BLACK_Rep_Voted', 'OTHER_Rep_Voted', 'TOTAL_Oth_Voted',
       'WHITE_Oth_Voted', 'BLACK_Oth_Voted', 'OTHER_Oth_Voted', 'TOTAL_Pct',
       'WHITE_Pct', 'BLACK_Pct', 'OTHER_Pct', 'TOTAL_Dem_Pct', 'WHITE_Dem_Pct',
       'BLACK_Dem_Pct', 'OTHER_Dem_Pct', 'TOTAL_Rep_Pct', 'WHITE_Rep_Pct',
       'BLACK_Rep_Pct', 'OTHER_Rep_Pct', 'TOTAL_Oth_Pct', 'WHITE_Oth_Pct',
       'BLACK_Oth_Pct', 'OTHER_Oth_Pct']

# %%
clean_vars = {"Reg":"registered voters",
             "Voted":"2024 general voters",
             "Pct":"turnout pct",
             "Dem":"Democratic party",
             "Rep":"Republican party",
             "Oth":"Other party"}

def clean_turnout(col):
    chunks = col.split("_")
    if len(chunks) == 2:
        return chunks[0].title() + " " + clean_vars[chunks[1]]
    else:
        return chunks[0].title() + " " + clean_vars[chunks[2]]+ " " + clean_vars[chunks[1]]

# %%
for col in turnout_cols:
    fields_dict[col] = clean_turnout(col)

# %%
fields_dict
# Out:
# {'G24A1NO': 'NO-:-CA No. 1 (Act No. 408, 2024 - HB 300) -- Provides relative to federal proceeds from alternative energy production',
#  'G24A1YES': 'YES-:-CA No. 1 (Act No. 408, 2024 - HB 300) -- Provides relative to federal proceeds from alternative energy production',
#  'G24PREDHAR': 'Kamala D. Harris, Tim Walz Democratic (DEM)-:-Presidential Electors',
#  'G24PRELOLI': 'Chase Oliver, Mike ter Maat Libertarian (LBT)-:-Presidential Electors',
#  'G24PREOCRU': 'Claudia de la Cruz, Karina Garcia Socialism and Liberation (OTHER)-:-Presidential Electors',
#  'G24PREOFRU': 'Rachele Fruit, Dennis Richter Socialist Workers Party (OTHER)-:-Presidential Electors',
#  'G24PREOKEN': 'Robert F. Kennedy, Jr., Nicole Shanahan We The People (OTHER)-:-Presidential Electors',
#  'G24PREOPRE': 'Mattie Preston, Shannel Conner Godliness, Truth, Justice (OTHER)-:-Presidential Electors',
#  'G24PREOSON': 'Peter Sonski, Lauren Onak American Solidarity Party (OTHER)-:-Presidential Electors',
#  'G24PREOSTE': 'Jill Stein, Ajamu Baraka Green (GRN)-:-Presidential Electors',
#  'G24PREOTER': 'Randall Terry, Stephen Broden Constitution Party (OTHER)-:-Presidential Electors',
#  'G24PREOWES': 'Cornel West, Melina Abdullah Justice For All (OTHER)-:-Presidential Electors',
#  'G24PRERTRU': 'Donald J. Trump, "JD" Vance Republican (REP)-:-Presidential Electors',
#  'GCON01DMAN': 'Mel Manuel (DEM)-:-U. S. Representative -- 1st Congressional District',
#  'GCON01NHYE': 'J. "Frankie" Hyers (NOPTY)-:-U. S. Representative -- 1st Congressional District',
#  'GCON01RARR': 'Randall Arrington (REP)-:-U. S. Representative -- 1st Congressional District',
#  'GCON01RSCA': 'Steve Scalise (REP)-:-U. S. Representative -- 1st Congressional District',
#  'GCON01RSHA': 'Ross Shales (REP)-:-U. S. Representative -- 1st Congressional District',
#  'GCON02DCAR': 'Troy A. Carter, Sr. (DEM)-:-U. S. Representative -- 2nd Congressional District',
#  'GCON02DDAV': 'Devin Davis (DEM)-:-U. S. Representative -- 2nd Congressional District',
#  'GCON02RGRA': 'Devin Lance Graham (REP)-:-U. S. Representative -- 2nd Congressional District',
#  'GCON02RLYN': 'Christy Lynch (REP)-:-U. S. Representative -- 2nd Congressional District',
#  'GCON02RPER': 'Shondrell Perrilloux (REP)-:-U. S. Representative -- 2nd Congressional District',
#  'GCON03DGON': 'Priscilla Gonzalez (DEM)-:-U. S. Representative -- 3rd Congressional District',
#  'GCON03DSUM': 'Sadi Summerlin (DEM)-:-U. S. Representative -- 3rd Congressional District',
#  'GCON03RHIG': 'Clay Higgins (REP)-:-U. S. Representative -- 3rd Congressional District',
#  'GCON03RJOH': '"Xan" John (REP)-:-U. S. Representative -- 3rd Congressional District',
#  'GCON04RJOH': '"Mike" Johnson (REP)-:-U. S. Representative -- 4th Congressional District',
#  'GCON04RMOR': 'Joshua Morott (REP)-:-U. S. Representative -- 4th Congressional District',
#  'GCON05DVAL': 'Michael Vallien, Jr. (DEM)-:-U. S. Representative -- 5th Congressional District',
#  'GCON05RLET': 'Julia Letlow (REP)-:-U. S. Representative -- 5th Congressional District',
#  'GCON05RMEN': 'M.V. "Vinny" Mendoza (REP)-:-U. S. Representative -- 5th Congressional District',
#  'GCON06DAND': 'Quentin Anthony Anderson (DEM)-:-U. S. Representative -- 6th Congressional District',
#  'GCON06DFIE': 'Cleo Fields (DEM)-:-U. S. Representative -- 6th Congressional District',
#  'GCON06DJON': 'Wilken Jones, Jr. (DEM)-:-U. S. Representative -- 6th Congressional District',
#  'GCON06DWIL': 'Peter Williams (DEM)-:-U. S. Representative -- 6th Congressional District',
#  'GCON06RGUI': 'Elbert Guillory (REP)-:-U. S. Representative -- 6th Congressional District',
#  'TOTAL_Reg': 'Total registered voters',
#  'WHITE_Reg': 'White registered voters',
#  'BLACK_Reg': 'Black registered voters',
#  'OTHER_Reg': 'Other registered voters',
#  'TOTAL_Dem_Reg': 'Total registered voters Democratic party',
#  'WHITE_Dem_Reg': 'White registered voters Democratic party',
#  'BLACK_Dem_Reg': 'Black registered voters Democratic party',
#  'OTHER_Dem_Reg': 'Other registered voters Democratic party',
#  'TOTAL_Rep_Reg': 'Total registered voters Republican party',
#  'WHITE_Rep_Reg': 'White registered voters Republican party',
#  'BLACK_Rep_Reg': 'Black registered voters Republican party',
#  'OTHER_Rep_Reg': 'Other registered voters Republican party',
#  'TOTAL_Oth_Reg': 'Total registered voters Other party',
#  'WHITE_Oth_Reg': 'White registered voters Other party',
#  'BLACK_Oth_Reg': 'Black registered voters Other party',
#  'OTHER_Oth_Reg': 'Other registered voters Other party',
#  'TOTAL_Voted': 'Total 2024 general voters',
#  'WHITE_Voted': 'White 2024 general voters',
#  'BLACK_Voted': 'Black 2024 general voters',
#  'OTHER_Voted': 'Other 2024 general voters',
#  'TOTAL_Dem_Voted': 'Total 2024 general voters Democratic party',
#  'WHITE_Dem_Voted': 'White 2024 general voters Democratic party',
#  'BLACK_Dem_Voted': 'Black 2024 general voters Democratic party',
#  'OTHER_Dem_Voted': 'Other 2024 general voters Democratic party',
#  'TOTAL_Rep_Voted': 'Total 2024 general voters Republican party',
#  'WHITE_Rep_Voted': 'White 2024 general voters Republican party',
#  'BLACK_Rep_Voted': 'Black 2024 general voters Republican party',
#  'OTHER_Rep_Voted': 'Other 2024 general voters Republican party',
#  'TOTAL_Oth_Voted': 'Total 2024 general voters Other party',
#  'WHITE_Oth_Voted': 'White 2024 general voters Other party',
#  'BLACK_Oth_Voted': 'Black 2024 general voters Other party',
#  'OTHER_Oth_Voted': 'Other 2024 general voters Other party',
#  'TOTAL_Pct': 'Total turnout pct',
#  'WHITE_Pct': 'White turnout pct',
#  'BLACK_Pct': 'Black turnout pct',
#  'OTHER_Pct': 'Other turnout pct',
#  'TOTAL_Dem_Pct': 'Total turnout pct Democratic party',
#  'WHITE_Dem_Pct': 'White turnout pct Democratic party',
#  'BLACK_Dem_Pct': 'Black turnout pct Democratic party',
#  'OTHER_Dem_Pct': 'Other turnout pct Democratic party',
#  'TOTAL_Rep_Pct': 'Total turnout pct Republican party',
#  'WHITE_Rep_Pct': 'White turnout pct Republican party',
#  'BLACK_Rep_Pct': 'Black turnout pct Republican party',
#  'OTHER_Rep_Pct': 'Other turnout pct Republican party',
#  'TOTAL_Oth_Pct': 'Total turnout pct Other party',
#  'WHITE_Oth_Pct': 'White turnout pct Other party',
#  'BLACK_Oth_Pct': 'Black turnout pct Other party',
#  'OTHER_Oth_Pct': 'Other turnout pct Other party',
#  'UNIQUE_ID': 'Unique ID for each precinct',
#  'COUNTYFP': 'County FIP identifier',
#  'Parish': 'Parish Name',
#  'Precinct': 'Precinct Name'}

# %%
### Create README

fields_dict['UNIQUE_ID']='Unique ID for each precinct'
fields_dict['COUNTYFP']='County FIP identifier'
fields_dict['Parish']='Parish Name'
fields_dict['Precinct']='Precinct Name'

title = "Louisiana 2024 General Election Precinct-Level Results and Turnout"
retrieval_date = "12/19/24"
fields_dict = fields_dict
github_link = "UPDATE LINK"
file_folder = "./la_2024_gen_prec_turnout/"
source = "Louisiana Secretary of State"

# %%
def full_readme_text(title, retrieval_date, source, fields_dict, github_link):

#First section of README
    readme_p1 = '''{title}\n
## RDH Date Retrieval
{retrieval_date}

## Sources
{source}

## Fields:
'''.format(title = title, source = source, retrieval_date = retrieval_date)

#Second section of README
    fields_table = pd.DataFrame.from_dict(fields_dict.items())
    fields_table.columns = ["Field Name", "Description"]
    readme_p2 = fields_table.to_string(formatters={'Description':'{{:<{}s}}'.format(fields_table['Description'].str.len().max()).format, 'Field Name':'{{:<{}s}}'.format(fields_table['Field Name'].str.len().max()).format}, index=False, justify = "left")

#Third section of README
    readme_p3 = '''\n
## Processing Steps
Visit the RDH GitHub and the processing script for this code [here]({github_link})

Please direct questions related to processing this dataset to info@redistrictingdatahub.org.
'''.format(github_link=github_link)
    
    full_readme = str(readme_p1)+str(readme_p2)+str(readme_p3)
    return full_readme

# %%
if not os.path.exists(file_folder):
    os.mkdir(file_folder)

with open(file_folder+"README_copy.txt", 'w') as tf:
        tf.write(full_readme_text(title, retrieval_date, source, fields_dict, github_link))
